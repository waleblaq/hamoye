# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
color = sns.color_palette()

# %%
data= pd.read_csv('energydata_complete.csv')

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
# date           19735 non-null object
# Appliances     19735 non-null int64
# lights         19735 non-null int64
# T1             19735 non-null float64
# RH_1           19735 non-null float64
# T2             19735 non-null float64
# RH_2           19735 non-null float64
# T3             19735 non-null float64
# RH_3           19735 non-null float64
# T4             19735 non-null float64
# RH_4           19735 non-null float64
# T5             19735 non-null float64
# RH_5           19735 non-null float64
# T6             19735 non-null float64
# RH_6           19735 non-null float64
# T7             19735 non-null float64
# RH_7           19735 non-null float64
# T8             19735 non-null float64
# RH_8           19735 non-null float64
# T9             19735 non-null float64
# RH_9           19735 non-null float64
# T_out          19735 non-null float64
# Press_mm_hg    19735 non-null float64
# RH_out         19735 non-null float64
# Windspeed      19735 non-null float64
# Visibility     19735 non-null float64
# Tdewpoint      19735 non-null float64
# rv1            19735 non-null float64
# rv2            19735 non-null float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
# lets visualize the histogram of all the features to understand the  distribution

data.hist(bins=20, figsize=(20,20));

# %%
data.drop(['date', 'lights'], inplace = True, axis = 1)

# %% [markdown]
# # QUESTION 12

# %%
X1= np.array(data['T2']).reshape(-1, 1)
y1 = data.T6

# %%
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression(normalize = True)
regressor1.fit(X1, y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
tpreds = regressor1.predict(X1)
trainscore = r2_score(y1, tpreds)
trainscore
# Out:
# 0.6418990830855493

# %%
###normalise the data set
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
S = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
# Out:
# C:\Users\olugbenle enoch\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X= S.drop(['Appliances'], axis = 1)
y = S['Appliances']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# from sklearn.preprocessing import PolynomialFeatures
# poly_reg = PolynomialFeatures(degree = 30)
# x_poly = poly_reg.fit_transform(X_train)
# x_polyt = poly_reg.fit_transform(X_test)
# poly_reg.fit(x_poly, y_train)
# lr2 = LinearRegression()
# lr2.fit(x_poly, y_train)
# predict = lr2.predict(poly_reg.fit(x_polyt, y_test))

# %%
preds = regressor.predict(X_test)

# %% [markdown]
# # QUESTION 13 AND 15 AND 16

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt
r2_score = r2_score(y_test, preds)
mae = mean_absolute_error(y_test, preds)
rms = sqrt(mean_squared_error(y_test, preds))
print('RMS =', rms , 'MAE =', mae, 'R-SQUARED =', r2_score)
# Out:
# RMS = 0.08751444947661711 MAE = 0.05013362397742955 R-SQUARED = 0.14890246319303524

# %% [markdown]
# # QUESTION 14

# %%
rss = np.sum(np.square(preds - y_test))
rss
# Out:
# 45.34762967266378

# %% [markdown]
# # QUESTION 18

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha = 0.4)
rr.fit(X_train, y_train)
rpreds = rr.predict(X_test)

# %%
rms = sqrt(mean_squared_error(y_test, rpreds))
rms
# Out:
# 0.08753385704628004

# %%
rss = np.sum(np.square(y_test - rpreds))
rss
# Out:
# 45.36774486216905

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
r2_score = r2_score(y_test, rpreds)
mae = mean_squared_error(y_test, rpreds)
rms = sqrt(mean_squared_error(y_test, rpreds))
print('RMS =', rms , 'MAE =', mae, 'R-SQUARED =', r2_score)
# Out:
# RMS = 0.08753385704628004 MAE = 0.00766217612939859 R-SQUARED = 0.1485249354509257

# %% [markdown]
# # QUESTION 20

# %%
from sklearn.linear_model import Lasso
lr = Lasso(alpha = 0.001)
lr.fit(X_train, y_train)
Lpreds = lr.predict(X_test)

# %%
rms = sqrt(mean_squared_error(y_test, Lpreds))
rms
# Out:
# 0.09358170467245137

# %%
rss = np.sum(np.square(y_test - Lpreds))
rss
# Out:
# 51.85336739590869

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
r2_score = r2_score(y_test, Lpreds)
mae = mean_absolute_error(y_test, Lpreds)
rms = sqrt(mean_squared_error(y_test, Lpreds))
print('RMS =', rms , 'MAE =', mae, 'R-SQUARED =', r2_score)
# Out:
# RMS = 0.09358170467245137 MAE = 0.055256639821262235 R-SQUARED = 0.026800880567125818

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ["features", col_name]
    weights_df[col_name].round(3)
    return weights_df

# %% [markdown]
# # QUESTION 19

# %%
lr_weights = get_weights_df(lr, X_train, 'lr_weights')
lr_weights
# Out:
#        features  lr_weights
# 0        RH_out   -0.049557
# 1          RH_8   -0.000110
# 2            T1    0.000000
# 3     Tdewpoint    0.000000
# 4    Visibility    0.000000
# 5   Press_mm_hg   -0.000000
# 6         T_out    0.000000
# 7          RH_9   -0.000000
# 8            T9   -0.000000
# 9            T8    0.000000
# 10         RH_7   -0.000000
# 11          rv1   -0.000000
# 12           T7   -0.000000
# 13           T6    0.000000
# 14         RH_5    0.000000
# 15           T5   -0.000000
# 16         RH_4    0.000000
# 17           T4   -0.000000
# 18         RH_3    0.000000
# 19           T3    0.000000
# 20         RH_2   -0.000000
# 21           T2    0.000000
# 22         RH_6   -0.000000
# 23          rv2   -0.000000
# 24    Windspeed    0.002912
# 25         RH_1    0.017880

# %%
rr_weights = get_weights_df(rr, X_train, 'rr_weights')
rr_weights
# Out:
#        features  rr_weights
# 0          RH_2   -0.411071
# 1         T_out   -0.262172
# 2            T2   -0.201397
# 3            T9   -0.188916
# 4          RH_8   -0.156830
# 5        RH_out   -0.054724
# 6          RH_7   -0.045977
# 7          RH_9   -0.041367
# 8            T5   -0.019853
# 9            T1   -0.018406
# 10          rv1    0.000748
# 11          rv2    0.000748
# 12  Press_mm_hg    0.006584
# 13           T7    0.010098
# 14   Visibility    0.012076
# 15         RH_5    0.016152
# 16         RH_4    0.024579
# 17           T4    0.027384
# 18    Windspeed    0.030268
# 19         RH_6    0.035519
# 20    Tdewpoint    0.083128
# 21         RH_3    0.095135
# 22           T8    0.101028
# 23           T6    0.217292
# 24           T3    0.288087
# 25         RH_1    0.519525

# %% [markdown]
# # QUESTION 17

# %%
regressor_weights = get_weights_df(regressor, X_train, 'regressor_weights')
regressor_weights
# Out:
#        features  regressor_weights
# 0          RH_2          -0.456698
# 1         T_out          -0.321860
# 2            T2          -0.236178
# 3            T9          -0.189941
# 4          RH_8          -0.157595
# 5        RH_out          -0.077671
# 6          RH_7          -0.044614
# 7          RH_9          -0.039800
# 8            T5          -0.015657
# 9            T1          -0.003281
# 10          rv1           0.000770
# 11          rv2           0.000770
# 12  Press_mm_hg           0.006839
# 13           T7           0.010319
# 14   Visibility           0.012307
# 15         RH_5           0.016006
# 16         RH_4           0.026386
# 17           T4           0.028981
# 18    Windspeed           0.029183
# 19         RH_6           0.038049
# 20         RH_3           0.096048
# 21           T8           0.101995
# 22    Tdewpoint           0.117758
# 23           T6           0.236425
# 24           T3           0.290627
# 25         RH_1           0.553547

# %%
final_weights = pd.merge(lr_weights, rr_weights, on = 'features')
final_weights = pd.merge(final_weights, regressor_weights, on = 'features')
final_weights
# Out:
#        features  lr_weights  rr_weights  regressor_weights
# 0        RH_out   -0.049557   -0.054724          -0.077671
# 1          RH_8   -0.000110   -0.156830          -0.157595
# 2            T1    0.000000   -0.018406          -0.003281
# 3     Tdewpoint    0.000000    0.083128           0.117758
# 4    Visibility    0.000000    0.012076           0.012307
# 5   Press_mm_hg   -0.000000    0.006584           0.006839
# 6         T_out    0.000000   -0.262172          -0.321860
# 7          RH_9   -0.000000   -0.041367          -0.039800
# 8            T9   -0.000000   -0.188916          -0.189941
# 9            T8    0.000000    0.101028           0.101995
# 10         RH_7   -0.000000   -0.045977          -0.044614
# 11          rv1   -0.000000    0.000748           0.000770
# 12           T7   -0.000000    0.010098           0.010319
# 13           T6    0.000000    0.217292           0.236425
# 14         RH_5    0.000000    0.016152           0.016006
# 15           T5   -0.000000   -0.019853          -0.015657
# 16         RH_4    0.000000    0.024579           0.026386
# 17           T4   -0.000000    0.027384           0.028981
# 18         RH_3    0.000000    0.095135           0.096048
# 19           T3    0.000000    0.288087           0.290627
# 20         RH_2   -0.000000   -0.411071          -0.456698
# 21           T2    0.000000   -0.201397          -0.236178
# 22         RH_6   -0.000000    0.035519           0.038049
# 23          rv2   -0.000000    0.000748           0.000770
# 24    Windspeed    0.002912    0.030268           0.029183
# 25         RH_1    0.017880    0.519525           0.553547

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
tpreds = regressor.predict(X_train)
trainscore = r2_score(y_train, tpreds)
trainscore2 = r2_score(y_test, preds)
trainscore
# Out:
# 0.14471942308518737

# %%
trainscore2
# Out:
# 0.14890246319303524
