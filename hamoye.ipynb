# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
color = sns.color_palette()

# %%
dataset = pd.read_csv(r'C:\Users\olugbenle enoch\Desktop\wale\fuel_ferc1.csv')
print('dataset size:', dataset.shape )
# Out:
# dataset size: (29523, 11)

# %%
dataset.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
dataset.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
dataset['fuel_unit'].value_counts()
# Out:
# mcf       11354
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
dataset.groupby('fuel_type_code_pudl')['fuel_unit'].value_counts()
# Out:
# fuel_type_code_pudl  fuel_unit
# coal                 ton           8438
#                      mmbtu           52
#                      mcf              5
#                      bbl              1
# gas                  mcf          11333
#                      mmbtu           94
#                      ton              4
#                      bbl              2
# nuclear              gramsU         464
#                      kgU            110
#                      mwhth          100
#                      mwdth           95
#                      mmbtu           34
# oil                  bbl           7952
#                      gal             81
#                      mcf              7
#                      ton              3
# other                ton             77
#                      bbl             42
#                      mcf              9
#                      gal              3
# waste                ton            436
#                      bbl              1
# ...

# %%
dataset.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#finding the percentage of the m issing values
percentage = (180/ len(dataset['fuel_unit'])) * 100
percentage
# Out:
# 0.609694136774718

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x = dataset['fuel_cost_per_unit_burned'])

# %%
sns.boxplot(x = dataset['fuel_cost_per_unit_delivered'])

# %%
sns.boxplot(x = dataset['fuel_cost_per_mmbtu'])

# %%
q1 = dataset.quantile(0.25)
q3 = dataset.quantile(0.75)
IQR = q3 - q1
print(IQR)
# Out:
# utility_id_ferc1                1.210000e+02
# report_year                     1.200000e+01
# fuel_qty_burned                 1.410217e+06
# fuel_mmbtu_per_unit             1.598200e+01
# fuel_cost_per_unit_burned       4.190600e+01
# fuel_cost_per_unit_delivered    3.835850e+01
# fuel_cost_per_mmbtu             5.805000e+00
# dtype: float64

# %%
#there are so many outliers the fuel cost per unit burned column
#fewer in the fuel cost per unit delivered 
#and just one in the fuel cost per mmbtu

# %%
#to remove ouliers in our data set
#dataset = dataset[~((dataset < (q1 - 1.5 * IQR)) | (dataset > (q3 + 1.5 * IQR))).any(axis = 1)] 
#dataset.shape
#we will not run this cell so that we dont disturb our values for the purpose of the quiz
# Out:
# (22183, 11)

# %%
sns.boxplot(x = dataset['fuel_cost_per_mmbtu'])

# %%
sns.boxplot(x = dataset['fuel_cost_per_unit_delivered'])

# %%
sns.boxplot(x = dataset['fuel_cost_per_unit_burned'])

# %%
dataset.corr() 
plt.figure(figsize=(20,10)) 
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset['fuel_unit']=dataset.groupby('fuel_type_code_pudl').fuel_unit.transform(lambda x:x.fillna(x.mode()[0]))

# %%
col={"gas":"cyan","coal":"black","oil":"red","nuclear":"springgreen","waste":"saddlebrown","other":'slategray'}

# %%
sns.catplot(x='fuel_type_code_pudl', y='fuel_cost_per_unit_burned',palette=col, data=dataset)

# %%
dataset['fuel_type_code_pudl'].value_counts()
# Out:
# gas        11486
# coal        8547
# oil         8064
# nuclear      818
# waste        441
# other        167
# Name: fuel_type_code_pudl, dtype: int64

# %%
a= sns.pairplot(dataset, palette=col,height=4,aspect=0.7)

# %%
fuel_df1 = dataset.iloc[0:19000].reset_index(drop=True)
fuel_df2 = dataset.iloc[19000:].reset_index(drop=True)
#spliting dataframes

# %%
g=sns.lineplot(x='report_year', y='fuel_cost_per_unit_delivered', palette=col,data=fuel_df1)
#g.set_yscale("log")

# %%
u=sns.lineplot(x='fuel_type_code_pudl', y='fuel_cost_per_unit_burned', palette=col,data=dataset)
#u.set_yscale("log")

# %%
dataset.groupby('fuel_type_code_pudl')['fuel_unit'].value_counts()
# Out:
# fuel_type_code_pudl  fuel_unit
# coal                 ton           8489
#                      mmbtu           52
#                      mcf              5
#                      bbl              1
# gas                  mcf          11386
#                      mmbtu           94
#                      ton              4
#                      bbl              2
# nuclear              gramsU         479
#                      kgU            110
#                      mwhth          100
#                      mwdth           95
#                      mmbtu           34
# oil                  bbl           7973
#                      gal             81
#                      mcf              7
#                      ton              3
# other                ton            113
#                      bbl             42
#                      mcf              9
#                      gal              3
# waste                ton            440
#                      bbl              1
# ...

# %%
import scipy.stats as stats
kurtosis_scipy = stats.kurtosis(dataset['fuel_qty_burned'])
kurtosis_scipy
# Out:
# 651.2589365474387
